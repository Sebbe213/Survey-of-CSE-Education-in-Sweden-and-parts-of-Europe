# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
rates_df = pd.read_csv('employment_rates.csv');

rates_df = rates_df.style.set_table_styles([{
    "selector": "th, td", "props": [("text-align", "left")]}])

rates_df
# Out:
# <style type="text/css">
# #T_c1da7 th {
#   text-align: left;
# }
# #T_c1da7  td {
#   text-align: left;
# }
# </style>
# <table id="T_c1da7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1da7_level0_col0" class="col_heading level0 col0" >University</th>
#       <th id="T_c1da7_level0_col1" class="col_heading level0 col1" >Abbreviation</th>
#       <th id="T_c1da7_level0_col2" class="col_heading level0 col2" >Country</th>
#       <th id="T_c1da7_level0_col3" class="col_heading level0 col3" >Field</th>
#       <th id="T_c1da7_level0_col4" class="col_heading level0 col4" >UG, PG , PhD or Overall</th>
#       <th id="T_c1da7_level0_col5" class="col_heading level0 col5" >Employment Rate (%) </th>
#       <th id="T_c1da7_level0_col6" class="col_heading level0 col6" >Timeframe (Months)</th>
#       <th id="T_c1da7_level0_col7" class="col_heading level0 col7" >Year of Reporting</th>
# ...

# %%
sources_df = pd.read_csv('Sources.csv');
sources_df = sources_df.style.set_table_styles([{
    "selector": "th,td", "props":[("text-align", "left")]}])
sources_df
# Out:
# <style type="text/css">
# #T_caa19 th {
#   text-align: left;
# }
# #T_caa19 td {
#   text-align: left;
# }
# </style>
# <table id="T_caa19">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_caa19_level0_col0" class="col_heading level0 col0" >University</th>
#       <th id="T_caa19_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_caa19_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_caa19_row0_col0" class="data row0 col0" >Chalmers Tekniska Högskola (Chalmers)</td>
#       <td id="T_caa19_row0_col1" class="data row0 col1" >https://cdn1.utbudet.com/storage/ma/48048602e4914e569319fd3723eb5cca/80dfec45935d48359dc640bfa0fe348a/pdf/1978C8EE26F07EB3149B487F1A9883CEF0D4506F/PDF%20Chalmers_Studentrekrytering_2021.pdf</td>
#     </tr>
#     <tr>
#       <th id="T_caa19_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
field_df = pd.read_csv('field.csv');
field_df
# Out:
#                                                                          University  \
# 0          Chalmers Tekniska Högskola (Chalmers) – UG+PG (all engineering programs)
# 1                                 University of Gothenburg (IT/CS programs) – UG+PG
# 2                                 KTH Royal Institute of Technology – PG (master’s)
# 3                             KTH Royal Institute of Technology – UG+PG (all grads)
# 4                                 Norwegian Univ. of Science & Tech. (NTNU) – UG+PG
# 5       Universitat Politècnica de València (UPV) – UG (BSc Ingeniería Informática)
# 6                                      Gdańsk University of Technology (PG) – UG+PG
# 7                           Politechnika Warszawska (Warsaw Univ. of Tech.) – UG+PG
# 8                           Politecnico di Milano (Polimi) – PG (Laurea Magistrale)
# 9                           Politecnico di Milano (Polimi) – PG (Laurea Magistrale)
# ...
